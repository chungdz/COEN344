# %%
import cv2 as cv
import pickle
import numpy as np
import math
from IPython.core.interactiveshell import InteractiveShell
from matplotlib import pyplot as plt
# InteractiveShell.ast_node_interactivity = "all"

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
d = unpickle('../data/data_batch_1')

# %%
s_visited = [0] * 10
pic_array = []
total = 0
for index, labels in enumerate(d[b'labels']):
    if s_visited[labels] == 0:
        pic_array.append(d[b'data'][index].reshape(3, 32, 32))
        total += 1
        s_visited[labels] = 1
        if total >= 10:
            break

# %%
len(pic_array)
# Out:
# 10

# %%
def show_pic(img, rank):

    img = img.transpose(1, 2, 0)
    
    dst = cv.Canny(img, 50, 200)
    f, axarr = plt.subplots(1, 2, figsize=(8.5, 8.5)) 
    axarr[0].imshow(img)
    axarr[1].imshow(dst, cmap='gray', vmin=0, vmax=255)
    plt.show()
    
    para_list = [[1, np.pi / 180, 18], [1, np.pi / 180, 20], [1.1, np.pi / 180, 20], [1, np.pi * 2 / 180, 20], [1.1, np.pi * 1.9 / 180, 20]]
    img_list = []
    for para in para_list:
        lines = cv.HoughLines(dst, para[0], para[1], para[2])
        cdst = cv.cvtColor(img, cv.COLOR_RGB2BGR)
        if lines is not None:
            for i in range(0, len(lines)):
                rho = lines[i][0][0]
                theta = lines[i][0][1]
                a = math.cos(theta)
                b = math.sin(theta)
                x0 = a * rho
                y0 = b * rho
                pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
                pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
                cv.line(cdst, pt1, pt2, (0, 0, 255), 1, cv.LINE_AA)
        res = cv.cvtColor(cdst, cv.COLOR_BGR2RGB)
        img_list.append(res)
    
    f, axarr = plt.subplots(1, 5, figsize=(15, 15))
    for i in range(5):
        axarr[i].imshow(img_list[i])
    plt.show()

# %%
for index, img in enumerate(pic_array):
    show_pic(img, index)

# %%
img = pic_array[1].transpose(1, 2, 0)
dst = cv.Canny(img, 50, 200)
f, axarr = plt.subplots(1, 2, figsize=(8.5, 8.5)) 
axarr[0].imshow(img)
axarr[1].imshow(dst, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
#  Standard Hough Line Transform
lines = cv.HoughLines(dst, 1, np.pi / 180, 18, None, 0, 0)
# Draw the lines
cdst = cv.cvtColor(img, cv.COLOR_RGB2BGR)
if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv.line(cdst, pt1, pt2, (0, 0, 255), 1, cv.LINE_AA)

# %%
#  Standard Hough Line Transform
lines = cv.HoughLines(dst, 1, np.pi / 180, 20, None, 0, 0)
# Draw the lines
cdst2 = cv.cvtColor(img, cv.COLOR_RGB2BGR)
if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv.line(cdst2, pt1, pt2, (0, 0, 255), 1, cv.LINE_AA)

# %%
#  Standard Hough Line Transform
lines = cv.HoughLines(dst, 1.1, np.pi / 180, 20, None, 0, 0)
# Draw the lines
cdst3 = cv.cvtColor(img, cv.COLOR_RGB2BGR)
if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv.line(cdst3, pt1, pt2, (0, 0, 255), 1, cv.LINE_AA)

# %%
#  Standard Hough Line Transform
lines = cv.HoughLines(dst, 1, np.pi * 2 / 180, 20, None, 0, 0)
# Draw the lines
cdst4 = cv.cvtColor(img, cv.COLOR_RGB2BGR)
if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv.line(cdst4, pt1, pt2, (0, 0, 255), 1, cv.LINE_AA)

# %%
res = cv.cvtColor(cdst, cv.COLOR_BGR2RGB)
res2 = cv.cvtColor(cdst2, cv.COLOR_BGR2RGB)
res3 = cv.cvtColor(cdst3, cv.COLOR_BGR2RGB)
res4 = cv.cvtColor(cdst4, cv.COLOR_BGR2RGB)
f, axarr = plt.subplots(1, 4, figsize=(15, 15)) 
axarr[0].imshow(res)
axarr[1].imshow(res2)
axarr[2].imshow(res3)
axarr[3].imshow(res4)
plt.show()

# %%
#  Standard Hough Line Transform
lines = cv.HoughLines(dst, 1, np.pi * 2 / 180, 19, None, 0, 0)
# Draw the lines
cdst5 = cv.cvtColor(img, cv.COLOR_RGB2BGR)
if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv.line(cdst5, pt1, pt2, (0, 0, 255), 1, cv.LINE_AA)
res5 = cv.cvtColor(cdst5, cv.COLOR_BGR2RGB)
plt.imshow(res5)
plt.show()

# %%
linesP = cv.HoughLinesP(dst, 1, np.pi / 180, 15, None, 10, 10)
cdstP = cv.cvtColor(img, cv.COLOR_RGB2BGR) 
if linesP is not None:
    for i in range(0, len(linesP)):
        l = linesP[i][0]
        cv.line(cdstP, (l[0], l[1]), (l[2], l[3]), (0, 0, 255), 1, cv.LINE_AA)

# %%
linesP = cv.HoughLinesP(dst, 1, np.pi / 180, 20, None, 10, 10)
cdstP2 = cv.cvtColor(img, cv.COLOR_RGB2BGR) 
if linesP is not None:
    for i in range(0, len(linesP)):
        l = linesP[i][0]
        cv.line(cdstP2, (l[0], l[1]), (l[2], l[3]), (0 ,0 , 255), 1, cv.LINE_AA)

# %%
resP = cv.cvtColor(cdstP, cv.COLOR_BGR2RGB)
resP2 = cv.cvtColor(cdstP2, cv.COLOR_BGR2RGB)
f, axarr = plt.subplots(1, 2, figsize=(8.5, 8.5)) 
axarr[0].imshow(resP)
axarr[1].imshow(resP2)
plt.show()

# %%
linesP = cv.HoughLinesP(dst, 1.2, np.pi / 180, 20, None, 10, 10)
cdstP3 = cv.cvtColor(img, cv.COLOR_RGB2BGR) 
if linesP is not None:
    for i in range(0, len(linesP)):
        l = linesP[i][0]
        cv.line(cdstP3, (l[0], l[1]), (l[2], l[3]), (0 ,0 , 255), 1, cv.LINE_AA)

# %%
linesP = cv.HoughLinesP(dst, 0.8, np.pi / 180, 20, None, 10, 10)
cdstP4 = cv.cvtColor(img, cv.COLOR_RGB2BGR) 
if linesP is not None:
    for i in range(0, len(linesP)):
        l = linesP[i][0]
        cv.line(cdstP4, (l[0], l[1]), (l[2], l[3]), (0 ,0 , 255), 1, cv.LINE_AA)

# %%
linesP = cv.HoughLinesP(dst, 1, np.pi * 2 / 180, 20, None, 10, 10)
cdstP5 = cv.cvtColor(img, cv.COLOR_RGB2BGR) 
if linesP is not None:
    for i in range(0, len(linesP)):
        l = linesP[i][0]
        cv.line(cdstP5, (l[0], l[1]), (l[2], l[3]), (0 ,0 , 255), 1, cv.LINE_AA)

# %%
linesP = cv.HoughLinesP(dst, 0.8, np.pi / 2 / 180, 20, None, 10, 10)
cdstP6 = cv.cvtColor(img, cv.COLOR_RGB2BGR) 
if linesP is not None:
    for i in range(0, len(linesP)):
        l = linesP[i][0]
        cv.line(cdstP6, (l[0], l[1]), (l[2], l[3]), (0 ,0 , 255), 1, cv.LINE_AA)

# %%
resP3 = cv.cvtColor(cdstP3, cv.COLOR_BGR2RGB)
resP4 = cv.cvtColor(cdstP4, cv.COLOR_BGR2RGB)
resP5 = cv.cvtColor(cdstP5, cv.COLOR_BGR2RGB)
resP6 = cv.cvtColor(cdstP6, cv.COLOR_BGR2RGB)
f, axarr = plt.subplots(1, 4, figsize=(15, 15)) 
axarr[0].imshow(resP3)
axarr[1].imshow(resP4)
axarr[2].imshow(resP5)
axarr[3].imshow(resP6)
plt.show()
